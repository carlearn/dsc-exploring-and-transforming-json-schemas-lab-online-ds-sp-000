# %% [markdown]
# # Exploring and Transforming JSON Schemas - Lab

# %% [markdown]
# # Introduction
#
# In this lab, you'll practice exploring a JSON file whose structure and schema is unknown to you. We will provide you with limited information, and you will explore the dataset to answer the specified question.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Use the JSON module to load and parse JSON documents
# * Explore and extract data using unknown JSON schemas
# * Convert JSON to a pandas dataframe

# %% [markdown]
# ## Your Task: Create a Bar Graph of the Top 10 States with the Highest Asthma Rates for Adults Age 18+
#
# The information you need to create this graph is located in `disease_data.json`. It contains both data and metadata.
#
# You are given the following codebook/data dictionary:
#
# * The actual data values are associated with the key `'DataValue'`
# * The state names are associated with the key `'LocationDesc'`
# * To filter to the appropriate records, make sure:
#   * The `'Question'` is `'Current asthma prevalence among adults aged >= 18 years'`
#   * The `'StratificationCategoryID1'` is `'OVERALL'`
#   * The `'DataValueTypeID'` is `'CRDPREV'`
#   * The `'LocationDesc'` is not `'United States'`
#
# The provided JSON file contains both data and metadata, and you will need to parse the metadata in order to understand the meanings of the values in the data.
#
# No further information about the structure of this file is provided.

# %% [markdown]
# ## Load the JSON File
#
# Load the data from the file `disease_data.json` into a variable `data`.

# %%
# Your code here 
import json
with open('disease_data.json') as f:
    data = json.load(f)

# %% [markdown]
# ## Explore the Overall Structure
#
# What is the overall data type of `data`?

# %%
# Your code here
type(data)
# Out:
# dict

# %% [markdown]
# What are the keys?

# %%
# Your code here
data.keys()
# Out:
# dict_keys(['meta', 'data'])

# %% [markdown]
# What are the data types associates with those keys?

# %%
# Your code here (data)
type(data['data'])
# Out:
# list

# %%
# Your code here (metadata)
type(data['meta'])
# Out:
# dict

# %% [markdown]
# Perform additional exploration to understand the contents of these values. For dictionaries, what are their keys? For lists, what is the length, and what does the first element look like?

# %%
print("Length of data list:", len(data['data']))
print("First element of data list:")
print(data['data'][0])
# Out:
# Length of data list: 60266
# First element of data list:
# [1, 'FF49C41F-CE8D-46C4-9164-653B1227CF6F', 1, 1527194521, '959778', 1527194521, '959778', None, '2016', '2016', 'US', 'United States', 'BRFSS', 'Alcohol', 'Binge drinking prevalence among adults aged >= 18 years', None, '%', 'Crude Prevalence', '16.9', '16.9', '*', '50 States + DC: US Median', '16', '18', 'Overall', 'Overall', None, None, None, None, [None, None, None, None, None], None, '59', 'ALC', 'ALC2_2', 'CRDPREV', 'OVERALL', 'OVR', None, None, None, None]

# %%
# Your code here (add additional cells as needed)
len(data['data'])
# Out:
# 60266

# %%
data['data'][0]
# Out:
# [1,
#  'FF49C41F-CE8D-46C4-9164-653B1227CF6F',
#  1,
#  1527194521,
#  '959778',
#  1527194521,
#  '959778',
#  None,
#  '2016',
#  '2016',
#  'US',
#  'United States',
#  'BRFSS',
#  'Alcohol',
#  'Binge drinking prevalence among adults aged >= 18 years',
#  None,
#  '%',
#  'Crude Prevalence',
#  '16.9',
#  '16.9',
#  '*',
#  '50 States + DC: US Median',
#  '16',
#  '18',
#  'Overall',
#  'Overall',
#  None,
#  None,
#  None,
#  None,
#  [None, None, None, None, None],
#  None,
#  '59',
#  'ALC',
#  'ALC2_2',
#  'CRDPREV',
#  'OVERALL',
#  'OVR',
#  None,
#  None,
#  None,
#  None]

# %%
data['meta'].keys()
# Out:
# dict_keys(['view'])

# %%
type(data['meta']['view'])
# Out:
# dict

# %%
data['meta']['view'].keys()
# Out:
# dict_keys(['id', 'name', 'attribution', 'attributionLink', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'indexUpdatedAt', 'licenseId', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'columns', 'grants', 'license', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %% [markdown]
# As you likely identified, we have a list of lists forming the `'data'`. In order to make sense of that list of lists, we need to find the meaning of each index, i.e. the names of the columns.
#
# ## Identify the Column Names
#
# Look through the metadata to find the *names* of the columns, and assign that variable to `column_names`. This should be a list of strings. (If you just get the values associated with the `'columns'` key, you will have a list of dictionaries, not a list of strings.)

# %%
# Your code here (add additional cells as needed)

column_data = data['meta']['view']['columns']
type(column_data)
# Out:
# list

# %%
column_data[:3]
# Out:
# [{'id': -1,
#   'name': 'sid',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':sid',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'id',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':id',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']},
#  {'id': -1,
#   'name': 'position',
#   'dataTypeName': 'meta_data',
#   'fieldName': ':position',
#   'position': 0,
#   'renderTypeName': 'meta_data',
#   'format': {},
#   'flags': ['hidden']}]

# %%
column_names = [info['name'] for info in column_data]
column_names
# Out:
# ['sid',
#  'id',
#  'position',
#  'created_at',
#  'created_meta',
#  'updated_at',
#  'updated_meta',
#  'meta',
#  'YearStart',
#  'YearEnd',
#  'LocationAbbr',
#  'LocationDesc',
#  'DataSource',
#  'Topic',
#  'Question',
#  'Response',
#  'DataValueUnit',
#  'DataValueType',
#  'DataValue',
#  'DataValueAlt',
#  'DataValueFootnoteSymbol',
#  'DatavalueFootnote',
#  'LowConfidenceLimit',
#  'HighConfidenceLimit',
#  'StratificationCategory1',
#  'Stratification1',
#  'StratificationCategory2',
#  'Stratification2',
#  'StratificationCategory3',
#  'Stratification3',
#  'GeoLocation',
#  'ResponseID',
#  'LocationID',
#  'TopicID',
#  'QuestionID',
#  'DataValueTypeID',
#  'StratificationCategoryID1',
#  'StratificationID1',
#  'StratificationCategoryID2',
#  'StratificationID2',
#  'StratificationCategoryID3',
#  'StratificationID3']

# %% [markdown]
# The following code checks that you have the correct column names:

# %%
# Run this cell without changes

# 42 total columns
assert len(column_names) == 42

# Each name should be a string, not a dict
assert type(column_names[0]) == str and type(column_names[-1]) == str

# Check that we have some specific strings
assert "DataValue" in column_names
assert "LocationDesc" in column_names
assert "Question" in column_names
assert "StratificationCategoryID1" in column_names
assert "DataValueTypeID" in column_names

# %% [markdown]
# ## Filter Rows Based on Columns
#
# Recall that we only want to include records where:
#
# * The `'Question'` is `'Current asthma prevalence among adults aged >= 18 years'`
# * The `'StratificationCategoryID1'` is `'OVERALL'`
# * The `'DataValueTypeID'` is `'CRDPREV'`
# * The `'LocationDesc'` is not `'United States'`
#
# Combining knowledge of the data and metadata, filter out the rows of data that are not relevant.
#
# (You may find the `pandas` library useful here.)

# %%
# Your code here (add additional cells as needed)
import pandas as pd

# %%
df = pd.DataFrame(data=data['data'][1:], columns=column_names)
df.head(2)
# Out:
#    sid                                    id  position  created_at  \
# 0    2  F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521
# 1    3  65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521
#
#   created_meta  updated_at updated_meta  meta YearStart YearEnd  ...  \
# 0       959778  1527194521       959778  None      2016    2016  ...
# 1       959778  1527194521       959778  None      2016    2016  ...
#
#   LocationID TopicID QuestionID DataValueTypeID StratificationCategoryID1  \
# 0         01     ALC     ALC2_2         CRDPREV                   OVERALL
# 1         02     ALC     ALC2_2         CRDPREV                   OVERALL
#
#   StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0               OVR                      None              None
# 1               OVR                      None              None
#
#   StratificationCategoryID3 StratificationID3
# 0                      None              None
# 1                      None              None
#
# [2 rows x 42 columns]

# %%
# Transcribing the columns we are filtering based on
question_name = "Question"
category_name = "StratificationCategoryID1"
type_name = "DataValueTypeID"
location_name = "LocationDesc"

# Transcribing the values we are filtering for
question_value = "Current asthma prevalence among adults aged >= 18 years"
category_value = "OVERALL"
type_value = "CRDPREV"
location_value = "United States"

# %%
# Filtering the dataframe based on the criteria

relevant_records = df[
    (df[question_name] == question_value) &
    (df[category_name] == category_value) &
    (df[type_name] == type_value) &
    (df[location_name] != location_value)
]

relevant_records
# Out:
#        sid                                    id  position  created_at  \
# 9370  9369  6BEC61D0-E04B-44BA-8170-F7D6A4C40A09      9369  1527194523
# 9371  9370  5D6EDDA9-B241-4498-A262-ED20AB78C44C      9370  1527194523
# 9372  9371  5FCE0D49-11FD-4545-B9E7-14F503123105      9371  1527194523
# 9373  9372  68F151CE-3084-402C-B672-78A43FBDE287      9372  1527194523
# 9374  9373  D3F00ED2-A069-4E40-B42B-5A2528A91B6F      9373  1527194523
# 9375  9374  A8B4F198-D388-4663-B82B-936C5FB37428      9374  1527194523
# 9376  9375  B2FB1AEA-5E2A-4E7C-9A93-586EA18EBE99      9375  1527194523
# 9377  9376  7C5D70DE-DE95-4AAD-A666-2260B5A16363      9376  1527194523
# 9378  9377  1893C9A3-C6CE-4F47-A66F-85A4F89F244F      9377  1527194523
# 9379  9378  D47614E3-47D4-40D6-AC29-C434C876F3DF      9378  1527194523
# 9380  9379  B1F090FC-1E46-467C-8C7D-0B90022A36BB      9379  1527194523
# 9381  9380  BFF73DC1-4B7B-43AC-9797-5F244999B94A      9380  1527194523
# 9382  9381  35433725-2434-480F-8DA5-7D74D3CE9A5B      9381  1527194523
# 9383  9382  8EE36428-84FF-44DA-BABA-86836A3A6E47      9382  1527194523
# 9384  9383  992D61D5-06F9-4001-AA9B-0F9CE29E001C      9383  1527194523
# 9385  9384  5CC74C63-269D-4037-93EB-3048D5401548      9384  1527194523
# 9386  9385  49F933C4-2A17-4F75-B791-526573D3D99F      9385  1527194523
# 9387  9386  521713DD-8FF1-4232-8608-EA12E8007A4D      9386  1527194523
# 9388  9387  55EB767F-A700-4E21-93D4-0749ABA918DC      9387  1527194523
# 9389  9388  B39B1D7E-8D3A-4BE0-AC5D-4D499F3F30C7      9388  1527194523
# 9390  9389  219420E0-760B-4A02-B0FF-44E9051D34E7      9389  1527194523
# 9391  9390  E27F81E2-931C-469B-BE46-805EC12B8196      9390  1527194523
# 9392  9391  3481271B-7943-4A2F-9CEE-1EBCE30E5CB6      9391  1527194523
# 9393  9392  AC02F97B-445F-40E2-B429-837B256F27E3      9392  1527194523
# 9394  9393  17BE97D3-36B0-462C-A798-CFEE2E5C974C      9393  1527194523
# 9395  9394  53D09576-C3BE-45F3-AC0D-8A4D1B1484D9      9394  1527194523
# 9396  9395  991ACC7D-0ABB-4556-867B-EE4EAA719F0A      9395  1527194523
# 9397  9396  AD024790-0CC0-43A8-A72A-51A46B4C2533      9396  1527194523
# 9398  9397  C7692B0C-2B96-4ED1-B24F-9130A54FB75C      9397  1527194523
# 9399  9398  74FCA8E5-77AB-44A5-91DA-72673AC06AE5      9398  1527194523
# 9400  9399  B5808B62-230B-4411-9C32-7EDACF28D282      9399  1527194523
# 9401  9400  3A3C8CBF-9390-456F-AC50-288C76E913AF      9400  1527194523
# 9402  9401  A9C42246-0D3E-4D4C-BEC5-340F96D6E3DD      9401  1527194523
# 9403  9402  F16FC172-EDA8-4EA7-8C98-8A0AD5A4E1A9      9402  1527194523
# 9404  9403  82577FD1-022C-450D-9F94-BC0406EB1754      9403  1527194523
# 9405  9404  3A409CD0-793D-496F-B057-BCE2190D5DA1      9404  1527194523
# 9406  9405  85373C9C-B495-44E9-A059-6A6F4688932E      9405  1527194523
# 9407  9406  F635C6E2-87FD-412A-AB1D-CC5C5E68866D      9406  1527194523
# 9408  9407  30EA129F-4AEB-4EB6-8D86-4ECD13192D8A      9407  1527194523
# 9409  9408  8AF769A0-E6E7-4068-A5C7-AC94C41F5CE2      9408  1527194523
# 9410  9409  043707BE-2A59-43E2-B2EA-71490C2B1F61      9409  1527194523
# 9411  9410  2DFA337C-DE2C-43D2-9B8A-2CEEDB414B77      9410  1527194523
# 9412  9411  3A6C0ED2-AD01-4FB4-98CC-BAAB0567C0DB      9411  1527194523
# 9413  9412  DA122508-115D-40D6-B69F-E0A9078ED9FC      9412  1527194523
# 9414  9413  5071E1A5-78CA-43AA-8260-4B8668E298F1      9413  1527194523
# 9415  9414  D44E78AC-6A3B-49BE-BD06-2BE0BAF32407      9414  1527194523
# 9416  9415  3C55B777-A5D7-4647-8F6E-C18AC47DB4BC      9415  1527194523
# 9417  9416  64EDA017-2C34-4C67-A393-5D3D22C9658A      9416  1527194523
# 9418  9417  08F3DC50-0E08-4FC5-8D4C-C020627D1C0B      9417  1527194523
# 9419  9418  676864A9-3305-4524-AE8A-7FA5C29E821B      9418  1527194523
# 9420  9419  E2F93B4A-1B4C-4F7D-8C04-5C02C775623D      9419  1527194523
# 9421  9420  F54F90BC-FE44-4506-80B5-BE61F945B5FC      9420  1527194523
# 9422  9421  414E8E7D-A3EA-4E3F-81E0-78FCEFCC00BB      9421  1527194523
# 9423  9422  89C1CB3A-E017-42CD-8A60-48F7365972F0      9422  1527194523
#
#      created_meta  updated_at updated_meta  meta YearStart YearEnd  ...  \
# 9370       959778  1527194523       959778  None      2016    2016  ...
# 9371       959778  1527194523       959778  None      2016    2016  ...
# 9372       959778  1527194523       959778  None      2016    2016  ...
# 9373       959778  1527194523       959778  None      2016    2016  ...
# 9374       959778  1527194523       959778  None      2016    2016  ...
# 9375       959778  1527194523       959778  None      2016    2016  ...
# 9376       959778  1527194523       959778  None      2016    2016  ...
# 9377       959778  1527194523       959778  None      2016    2016  ...
# 9378       959778  1527194523       959778  None      2016    2016  ...
# 9379       959778  1527194523       959778  None      2016    2016  ...
# 9380       959778  1527194523       959778  None      2016    2016  ...
# 9381       959778  1527194523       959778  None      2016    2016  ...
# 9382       959778  1527194523       959778  None      2016    2016  ...
# 9383       959778  1527194523       959778  None      2016    2016  ...
# 9384       959778  1527194523       959778  None      2016    2016  ...
# 9385       959778  1527194523       959778  None      2016    2016  ...
# 9386       959778  1527194523       959778  None      2016    2016  ...
# 9387       959778  1527194523       959778  None      2016    2016  ...
# 9388       959778  1527194523       959778  None      2016    2016  ...
# 9389       959778  1527194523       959778  None      2016    2016  ...
# 9390       959778  1527194523       959778  None      2016    2016  ...
# 9391       959778  1527194523       959778  None      2016    2016  ...
# 9392       959778  1527194523       959778  None      2016    2016  ...
# 9393       959778  1527194523       959778  None      2016    2016  ...
# 9394       959778  1527194523       959778  None      2016    2016  ...
# 9395       959778  1527194523       959778  None      2016    2016  ...
# 9396       959778  1527194523       959778  None      2016    2016  ...
# 9397       959778  1527194523       959778  None      2016    2016  ...
# 9398       959778  1527194523       959778  None      2016    2016  ...
# 9399       959778  1527194523       959778  None      2016    2016  ...
# 9400       959778  1527194523       959778  None      2016    2016  ...
# 9401       959778  1527194523       959778  None      2016    2016  ...
# 9402       959778  1527194523       959778  None      2016    2016  ...
# 9403       959778  1527194523       959778  None      2016    2016  ...
# 9404       959778  1527194523       959778  None      2016    2016  ...
# 9405       959778  1527194523       959778  None      2016    2016  ...
# 9406       959778  1527194523       959778  None      2016    2016  ...
# 9407       959778  1527194523       959778  None      2016    2016  ...
# 9408       959778  1527194523       959778  None      2016    2016  ...
# 9409       959778  1527194523       959778  None      2016    2016  ...
# 9410       959778  1527194523       959778  None      2016    2016  ...
# 9411       959778  1527194523       959778  None      2016    2016  ...
# 9412       959778  1527194523       959778  None      2016    2016  ...
# 9413       959778  1527194523       959778  None      2016    2016  ...
# 9414       959778  1527194523       959778  None      2016    2016  ...
# 9415       959778  1527194523       959778  None      2016    2016  ...
# 9416       959778  1527194523       959778  None      2016    2016  ...
# 9417       959778  1527194523       959778  None      2016    2016  ...
# 9418       959778  1527194523       959778  None      2016    2016  ...
# 9419       959778  1527194523       959778  None      2016    2016  ...
# 9420       959778  1527194523       959778  None      2016    2016  ...
# 9421       959778  1527194523       959778  None      2016    2016  ...
# 9422       959778  1527194523       959778  None      2016    2016  ...
# 9423       959778  1527194523       959778  None      2016    2016  ...
#
#      LocationID TopicID QuestionID DataValueTypeID StratificationCategoryID1  \
# 9370         01     AST     AST1_1         CRDPREV                   OVERALL
# 9371         02     AST     AST1_1         CRDPREV                   OVERALL
# 9372         04     AST     AST1_1         CRDPREV                   OVERALL
# 9373         05     AST     AST1_1         CRDPREV                   OVERALL
# 9374         06     AST     AST1_1         CRDPREV                   OVERALL
# 9375         08     AST     AST1_1         CRDPREV                   OVERALL
# 9376         09     AST     AST1_1         CRDPREV                   OVERALL
# 9377         10     AST     AST1_1         CRDPREV                   OVERALL
# 9378         11     AST     AST1_1         CRDPREV                   OVERALL
# 9379         12     AST     AST1_1         CRDPREV                   OVERALL
# 9380         13     AST     AST1_1         CRDPREV                   OVERALL
# 9381         15     AST     AST1_1         CRDPREV                   OVERALL
# 9382         16     AST     AST1_1         CRDPREV                   OVERALL
# 9383         17     AST     AST1_1         CRDPREV                   OVERALL
# 9384         18     AST     AST1_1         CRDPREV                   OVERALL
# 9385         19     AST     AST1_1         CRDPREV                   OVERALL
# 9386         20     AST     AST1_1         CRDPREV                   OVERALL
# 9387         21     AST     AST1_1         CRDPREV                   OVERALL
# 9388         22     AST     AST1_1         CRDPREV                   OVERALL
# 9389         23     AST     AST1_1         CRDPREV                   OVERALL
# 9390         24     AST     AST1_1         CRDPREV                   OVERALL
# 9391         25     AST     AST1_1         CRDPREV                   OVERALL
# 9392         26     AST     AST1_1         CRDPREV                   OVERALL
# 9393         27     AST     AST1_1         CRDPREV                   OVERALL
# 9394         28     AST     AST1_1         CRDPREV                   OVERALL
# 9395         29     AST     AST1_1         CRDPREV                   OVERALL
# 9396         30     AST     AST1_1         CRDPREV                   OVERALL
# 9397         31     AST     AST1_1         CRDPREV                   OVERALL
# 9398         32     AST     AST1_1         CRDPREV                   OVERALL
# 9399         33     AST     AST1_1         CRDPREV                   OVERALL
# 9400         34     AST     AST1_1         CRDPREV                   OVERALL
# 9401         35     AST     AST1_1         CRDPREV                   OVERALL
# 9402         36     AST     AST1_1         CRDPREV                   OVERALL
# 9403         37     AST     AST1_1         CRDPREV                   OVERALL
# 9404         38     AST     AST1_1         CRDPREV                   OVERALL
# 9405         39     AST     AST1_1         CRDPREV                   OVERALL
# 9406         40     AST     AST1_1         CRDPREV                   OVERALL
# 9407         41     AST     AST1_1         CRDPREV                   OVERALL
# 9408         42     AST     AST1_1         CRDPREV                   OVERALL
# 9409         44     AST     AST1_1         CRDPREV                   OVERALL
# 9410         45     AST     AST1_1         CRDPREV                   OVERALL
# 9411         46     AST     AST1_1         CRDPREV                   OVERALL
# 9412         47     AST     AST1_1         CRDPREV                   OVERALL
# 9413         48     AST     AST1_1         CRDPREV                   OVERALL
# 9414         49     AST     AST1_1         CRDPREV                   OVERALL
# 9415         50     AST     AST1_1         CRDPREV                   OVERALL
# 9416         51     AST     AST1_1         CRDPREV                   OVERALL
# 9417         53     AST     AST1_1         CRDPREV                   OVERALL
# 9418         54     AST     AST1_1         CRDPREV                   OVERALL
# 9419         55     AST     AST1_1         CRDPREV                   OVERALL
# 9420         56     AST     AST1_1         CRDPREV                   OVERALL
# 9421         66     AST     AST1_1         CRDPREV                   OVERALL
# 9422         72     AST     AST1_1         CRDPREV                   OVERALL
# 9423         78     AST     AST1_1         CRDPREV                   OVERALL
#
#      StratificationID1 StratificationCategoryID2 StratificationID2  \
# 9370               OVR                      None              None
# 9371               OVR                      None              None
# 9372               OVR                      None              None
# 9373               OVR                      None              None
# 9374               OVR                      None              None
# 9375               OVR                      None              None
# 9376               OVR                      None              None
# 9377               OVR                      None              None
# 9378               OVR                      None              None
# 9379               OVR                      None              None
# 9380               OVR                      None              None
# 9381               OVR                      None              None
# 9382               OVR                      None              None
# 9383               OVR                      None              None
# 9384               OVR                      None              None
# 9385               OVR                      None              None
# 9386               OVR                      None              None
# 9387               OVR                      None              None
# 9388               OVR                      None              None
# 9389               OVR                      None              None
# 9390               OVR                      None              None
# 9391               OVR                      None              None
# 9392               OVR                      None              None
# 9393               OVR                      None              None
# 9394               OVR                      None              None
# 9395               OVR                      None              None
# 9396               OVR                      None              None
# 9397               OVR                      None              None
# 9398               OVR                      None              None
# 9399               OVR                      None              None
# 9400               OVR                      None              None
# 9401               OVR                      None              None
# 9402               OVR                      None              None
# 9403               OVR                      None              None
# 9404               OVR                      None              None
# 9405               OVR                      None              None
# 9406               OVR                      None              None
# 9407               OVR                      None              None
# 9408               OVR                      None              None
# 9409               OVR                      None              None
# 9410               OVR                      None              None
# 9411               OVR                      None              None
# 9412               OVR                      None              None
# 9413               OVR                      None              None
# 9414               OVR                      None              None
# 9415               OVR                      None              None
# 9416               OVR                      None              None
# 9417               OVR                      None              None
# 9418               OVR                      None              None
# 9419               OVR                      None              None
# 9420               OVR                      None              None
# 9421               OVR                      None              None
# 9422               OVR                      None              None
# 9423               OVR                      None              None
#
#      StratificationCategoryID3 StratificationID3
# 9370                      None              None
# 9371                      None              None
# 9372                      None              None
# 9373                      None              None
# 9374                      None              None
# 9375                      None              None
# 9376                      None              None
# 9377                      None              None
# 9378                      None              None
# 9379                      None              None
# 9380                      None              None
# 9381                      None              None
# 9382                      None              None
# 9383                      None              None
# 9384                      None              None
# 9385                      None              None
# 9386                      None              None
# 9387                      None              None
# 9388                      None              None
# 9389                      None              None
# 9390                      None              None
# 9391                      None              None
# 9392                      None              None
# 9393                      None              None
# 9394                      None              None
# 9395                      None              None
# 9396                      None              None
# 9397                      None              None
# 9398                      None              None
# 9399                      None              None
# 9400                      None              None
# 9401                      None              None
# 9402                      None              None
# 9403                      None              None
# 9404                      None              None
# 9405                      None              None
# 9406                      None              None
# 9407                      None              None
# 9408                      None              None
# 9409                      None              None
# 9410                      None              None
# 9411                      None              None
# 9412                      None              None
# 9413                      None              None
# 9414                      None              None
# 9415                      None              None
# 9416                      None              None
# 9417                      None              None
# 9418                      None              None
# 9419                      None              None
# 9420                      None              None
# 9421                      None              None
# 9422                      None              None
# 9423                      None              None
#
# [54 rows x 42 columns]

# %% [markdown]
# You should have 54 records after filtering.
#
# ## Extract the Attributes Required for Plotting
#
# For each record, the only information we actually need for the graph is the `'DataValue'` and `'LocationDesc'`. Create a list of records that only contains these two attributes.
#
# Also, make sure that the data values are numbers, not strings.

# %%
# Your code here (create additional cells as needed)

data_and_location = relevant_records[["DataValue", "LocationDesc"]].copy()
data_and_location["DataValue"] = data_and_location["DataValue"].apply(float)
data_and_location.head()
# Out:
#       DataValue LocationDesc
# 9370        9.7      Alabama
# 9371        8.8       Alaska
# 9372        9.4      Arizona
# 9373        8.5     Arkansas
# 9374        7.8   California

# %% [markdown]
# ## Find Top 10 States
#
# Sort by `'DataValue'` and limit to the first 10 records.

# %%
# Your code here (add additional cells as needed)
top_10 = data_and_location.sort_values("DataValue", ascending=False)[:10]
top_10
# Out:
#       DataValue   LocationDesc
# 9389       12.2          Maine
# 9401       11.8     New Mexico
# 9418       11.8  West Virginia
# 9387       11.6       Kentucky
# 9399       11.4  New Hampshire
# 9412       10.9      Tennessee
# 9392       10.9       Michigan
# 9381       10.7         Hawaii
# 9422       10.7    Puerto Rico
# 9409       10.7   Rhode Island

# %% [markdown]
# ## Separate the Names and Values for Plotting
#
# Assign the names of the top 10 states to a list-like variable `names`, and the associated values to a list-like variable `values`. Then the plotting code below should work correctly to make the desired bar graph.

# %%
# Replace None with appropriate code
names = top_10['LocationDesc']
values = top_10['DataValue']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %%
plt.barh(names, values, color = 'green')
plt.xlabel("Percent 18+ with Asthma")
plt.ylabel("State")
plt.title("Adult Asthma Rates by State in 2016")

plt.show()

# %%
# Run this cell without changes

fig, ax = plt.subplots()

ax.barh(names[::-1], values[::-1]) # Values inverted so highest is at top
ax.set_title('Adult Asthma Rates by State in 2016')
ax.set_xlabel('Percent 18+ with Asthma');

# %% [markdown]
# ## Summary
#
# Well done! In this lab you got some extended practice exploring the structure of JSON files and visualizing data!
